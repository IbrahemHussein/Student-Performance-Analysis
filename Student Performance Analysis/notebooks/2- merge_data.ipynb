# %% [markdown]
# # import library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <h1>import the data </h1>
# <p> we have scripted the data and save it into 5 files</p>

# %%
df1=pd.read_csv('../data/external/student_data_1.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  student_id                 Student_name  \
# 0             0           0     1002330        ابراهيم سعيد محمد فرج
# 1             1           1     1002331        احمد حسام السيد حارون
# 2             2           2     1002332      احمد صلاح حسن احمد جعفر
# 3             3           3     1002333  توفيق محمد توفيق مهران قاسم
# 4             4           4     1002334           زياد حسن محمد احمد
#
#                            School Administration Division Student_status  \
# 0  النور ث للمكفوفين بالجيزة بنين          الدقى     أدبي           ناجح
# 1  النور ث للمكفوفين بالجيزة بنين          الدقى     أدبي           ناجح
# 2  النور ث للمكفوفين بالجيزة بنين          الدقى     أدبي           ناجح
# 3  النور ث للمكفوفين بالجيزة بنين          الدقى     أدبي           ناجح
# 4  النور ث للمكفوفين بالجيزة بنين          الدقى     أدبي           ناجح
#
#   Arabic English  ... chemistry   biology   Geology AppliedMathematics  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9037 entries, 0 to 9036
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0.1              9037 non-null   int64
#  1   Unnamed: 0                9037 non-null   int64
#  2   student_id                9037 non-null   int64
#  3   Student_name              9037 non-null   object
#  4   School                    9037 non-null   object
#  5   Administration            9037 non-null   object
#  6   Division                  9037 non-null   object
#  7   Student_status            9037 non-null   object
#  8   Arabic                    9037 non-null   object
#  9   English                   9037 non-null   object
#  10  French                    9037 non-null   object
#  11  pure_mathematics          9037 non-null   object
#  12  history                   9037 non-null   object
# ...

# %% [markdown]
# notes about first file of data
# > 1. columns  `Unnamed: 0` ,`1 Unnamed: 0` that should be dropped

# %%
df1.drop(['Unnamed: 0.1','Unnamed: 0'],axis=1,inplace=True)

# %%
df2=pd.read_csv('../data/external/student_data_2.csv')

# %%
df2.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  student_id  \
# 0             0           0.0         0.0     1018501
# 1             1           1.0         1.0     1018502
# 2             2           2.0         2.0     1018503
# 3             3           3.0         3.0     1018505
# 4             4           4.0         4.0     1018506
#
#                         Student_name  \
# 0             يوسف احمد اسماعيل محمد
# 1             يوسف زكريا سند ابراهيم
# 2              يوسف زناتي يوسف زناتي
# 3  يوسف عمرو عبدالهادي المرسي المرسي
# 4            يوسف مجدي سعيد جاب الله
#
#                                       School Administration   Division  \
# 0  الشهيد الرائد عبد الرحمن مهدي حسن الصيرفى        العجوزة  علمي علوم
# 1  الشهيد الرائد عبد الرحمن مهدي حسن الصيرفى        العجوزة  علمي علوم
# 2  الشهيد الرائد عبد الرحمن مهدي حسن الصيرفى        العجوزة  علمي علوم
# 3  الشهيد الرائد عبد الرحمن مهدي حسن الصيرفى        العجوزة  علمي علوم
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13543 entries, 0 to 13542
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0.2              13543 non-null  int64
#  1   Unnamed: 0.1              7677 non-null   float64
#  2   Unnamed: 0                1401 non-null   float64
#  3   student_id                13543 non-null  int64
#  4   Student_name              13543 non-null  object
#  5   School                    13543 non-null  object
#  6   Administration            13543 non-null  object
#  7   Division                  13543 non-null  object
#  8   Student_status            13543 non-null  object
#  9   Arabic                    13542 non-null  object
#  10  English                   13542 non-null  object
#  11  French                    13542 non-null  object
#  12  pure_mathematics          13543 non-null  object
# ...

# %%
df2.drop(['Unnamed: 0.1','Unnamed: 0.2','Unnamed: 0'],axis=1,inplace=True)

# %%
df3=pd.read_csv('../data/external/student_data_3.csv')

# %%
df3.head()
# Out:
#    Unnamed: 0  student_id                      Student_name         School  \
# 0           0     1035002             شهد عزت فتحي حافظ فضل  كرداسة ث بنات
# 1           1     1035004                  شهد علي حسن حمدي  كرداسة ث بنات
# 2           2     1035005          شهد فريد رجب علي الصعيدي  كرداسة ث بنات
# 3           3     1035006  شهد كمال السيد محمد احمد الصعيدي  كرداسة ث بنات
# 4           4     1035007  شهد محمد حامد عبدالله عبدالمقصود  كرداسة ث بنات
#
#   Administration   Division Student_status Arabic English French  ...  \
# 0         كرداسة  علمي علوم   راسب دور أول     40      25     20  ...
# 1         كرداسة  علمي علوم           ناجح     40      25     20  ...
# 2         كرداسة  علمي علوم   راسب دور أول     40      25     20  ...
# 3         كرداسة  علمي علوم           ناجح   44.5      25     21  ...
# 4         كرداسة  علمي علوم           ناجح     52      25     36  ...
#
#   chemistry biology Geology AppliedMathematics Physics Total Score  \
# ...

# %%
df3.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df4=pd.read_csv('../data/external/student_data_4.csv')

# %%
df4.head()
# Out:
#    Unnamed: 0  student_id              Student_name          School  \
# 0           0     1060000       شهد محمد حمدي عمران  اهناسيا ث بنات
# 1           1     1060001     شهد محمد روبي ابوسريع  اهناسيا ث بنات
# 2           2     1060002       شهد محمود رياض شفيق  اهناسيا ث بنات
# 3           3     1060004  شهد مختار عبدالعزيز موسي  اهناسيا ث بنات
# 4           4     1060005        شهد ناصر سيد شعبان  اهناسيا ث بنات
#
#   Administration   Division Student_status Arabic English French  ...  \
# 0        اهناسيا  علمي علوم           ناجح     47      25     34  ...
# 1        اهناسيا  علمي علوم   راسب دور أول     60    غائب     37  ...
# 2        اهناسيا  علمي علوم           ناجح   61.5      36   36.5  ...
# 3        اهناسيا  علمي علوم           ناجح     52      31     29  ...
# 4        اهناسيا  علمي علوم           ناجح     57      33   39.5  ...
#
#   chemistry biology Geology AppliedMathematics Physics Total Score  \
# ...

# %%
df4.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df5=pd.read_csv('../data/external/student_data_5.csv')

# %%
df5.head()
# Out:
#    Unnamed: 0  student_id                    Student_name  \
# 0           0     1075000  مريم محمد حارث توفيق عبدالرحيم
# 1           1     1075001          مريم محمد صلاح ابراهيم
# 2           2     1075002             مريم محمد عادل احمد
# 3           3     1075003             مريم محمود حسن زيان
# 4           4     1075004             مريم مصطفي حسن محمد
#
#                   School Administration Division Student_status Arabic  \
# 0  خدمات الاورمان ث بنات          الدقى     أدبي           ناجح   46.5
# 1  خدمات الاورمان ث بنات          الدقى     أدبي           ناجح     43
# 2  خدمات الاورمان ث بنات          الدقى     أدبي           ناجح     53
# 3  خدمات الاورمان ث بنات          الدقى     أدبي           ناجح     41
# 4  خدمات الاورمان ث بنات          الدقى     أدبي   راسب دور أول     26
#
#   English French  ... chemistry   biology   Geology AppliedMathematics  \
# 0      32     26  ...  غير مقرر  غير مقرر  غير مقرر           غير مقرر
# ...

# %%
#drop Unnamed: 0
df5.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14220 entries, 0 to 14219
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   student_id                14220 non-null  int64
#  1   Student_name              14220 non-null  object
#  2   School                    14220 non-null  object
#  3   Administration            14220 non-null  object
#  4   Division                  14220 non-null  object
#  5   Student_status            14220 non-null  object
#  6   Arabic                    14213 non-null  object
#  7   English                   14212 non-null  object
#  8   French                    14214 non-null  object
#  9   pure_mathematics          14220 non-null  object
#  10  history                   14220 non-null  object
#  11  geography                 14220 non-null  object
#  12  philosophy                14220 non-null  object
# ...

# %%
df6=pd.read_csv('../data/external/student_data_6.csv')

# %%
df6.head()
# Out:
#    Unnamed: 0  student_id                   Student_name  \
# 0           0     1100000           نوران خالد محمد انور
# 1           1     1100001  بسمه خلف الله صوفي كامل منجود
# 2           2     1100002           مروه محمود مصطفي علي
# 3           3     1100005            سماح محمد معوض كامل
# 4           4     1100007    امل فرج عبدالرحمن عبدالعزيز
#
#                         School Administration   Division Student_status  \
# 0  منازل ادارة غرب الفيوم بنات     غرب الفيوم       أدبي           ناجح
# 1  منازل ادارة غرب الفيوم بنات     غرب الفيوم  علمي علوم   راسب دور أول
# 2  منازل ادارة غرب الفيوم بنات     غرب الفيوم  علمي علوم   راسب دور أول
# 3  منازل ادارة غرب الفيوم بنات     غرب الفيوم  علمي علوم   راسب دور أول
# 4  منازل ادارة غرب الفيوم بنات     غرب الفيوم  علمي علوم   راسب دور أول
#
#   Arabic English French  ... chemistry   biology   Geology AppliedMathematics  \
# 0     43      43     20  ...  غير مقرر  غير مقرر  غير مقرر           غير مقرر
# ...

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12910 entries, 0 to 12909
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                12910 non-null  int64
#  1   student_id                12910 non-null  int64
#  2   Student_name              12910 non-null  object
#  3   School                    12910 non-null  object
#  4   Administration            12910 non-null  object
#  5   Division                  12910 non-null  object
#  6   Student_status            12910 non-null  object
#  7   Arabic                    12907 non-null  object
#  8   English                   12910 non-null  object
#  9   French                    12905 non-null  object
#  10  pure_mathematics          12910 non-null  object
#  11  history                   12910 non-null  object
#  12  geography                 12910 non-null  object
# ...

# %% [markdown]
# <h3> last step to merge the data into one file </h3>

# %%
df=pd.concat([df1,df2,df3,df4,df5,df6])

# %%
df.head()
# Out:
#    student_id                 Student_name                          School  \
# 0     1002330        ابراهيم سعيد محمد فرج  النور ث للمكفوفين بالجيزة بنين
# 1     1002331        احمد حسام السيد حارون  النور ث للمكفوفين بالجيزة بنين
# 2     1002332      احمد صلاح حسن احمد جعفر  النور ث للمكفوفين بالجيزة بنين
# 3     1002333  توفيق محمد توفيق مهران قاسم  النور ث للمكفوفين بالجيزة بنين
# 4     1002334           زياد حسن محمد احمد  النور ث للمكفوفين بالجيزة بنين
#
#   Administration Division Student_status Arabic English French  \
# 0          الدقى     أدبي           ناجح     48      25   31.0
# 1          الدقى     أدبي           ناجح     56      41   40.0
# 2          الدقى     أدبي           ناجح     53      25   37.0
# 3          الدقى     أدبي           ناجح     79      37   38.0
# 4          الدقى     أدبي           ناجح     65      36   40.0
#
#   pure_mathematics  ...   biology   Geology AppliedMathematics   Physics  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83592 entries, 0 to 12909
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   student_id                83592 non-null  int64
#  1   Student_name              83592 non-null  object
#  2   School                    83592 non-null  object
#  3   Administration            83592 non-null  object
#  4   Division                  83592 non-null  object
#  5   Student_status            83592 non-null  object
#  6   Arabic                    83560 non-null  object
#  7   English                   83561 non-null  object
#  8   French                    83559 non-null  object
#  9   pure_mathematics          83591 non-null  object
#  10  history                   83592 non-null  object
#  11  geography                 83592 non-null  object
#  12  philosophy                83592 non-null  object
# ...

# %%
df.shape
# Out:
# (83592, 25)

# %%
df.to_csv('../data/processed/student_data.csv')

# %% [markdown]
# # Summary
# > 1. we can see that the 21 columns is object type and it not correct we should fixed it
# > 2. `Religious Education` ,`Citizenship Education` and `Economics and Statistics` :They are subjects that are not added to the total score that determines the student’s level, but the student must succeed in them
# > 3. final data is contains of `70682` rows  and `24` columns
# > 4.  data don't contain any missing values
# > 5. We can notice some things from the data: the student is divided into sections, and on this basis they are examined in some subjects specific to their specialization, and subjects that are not specific to the student’s specialization are written as unscheduled.
# > 6. These are the columns that will still contain text, while the rest of the columns will have their data type changed

# %% [markdown]
# <h1 style="text-align:center;">data is collected .</h1>
