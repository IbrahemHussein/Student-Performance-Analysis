# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import klib
import plotly_express as px
from geopy.geocoders import Nominatim

# %%
df=pd.read_csv('../data/processed/student_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0.1  student_id                 Student_name  \
# 0             0     1002330        ابراهيم سعيد محمد فرج
# 1             1     1002331        احمد حسام السيد حارون
# 2             2     1002332      احمد صلاح حسن احمد جعفر
# 3             3     1002333  توفيق محمد توفيق مهران قاسم
# 4             4     1002334           زياد حسن محمد احمد
#
#                            School Administration Division Student_status  \
# 0  النور ث للمكفوفين بالجيزة بنين          الدقى     أدبي           ناجح
# 1  النور ث للمكفوفين بالجيزة بنين          الدقى     أدبي           ناجح
# 2  النور ث للمكفوفين بالجيزة بنين          الدقى     أدبي           ناجح
# 3  النور ث للمكفوفين بالجيزة بنين          الدقى     أدبي           ناجح
# 4  النور ث للمكفوفين بالجيزة بنين          الدقى     أدبي           ناجح
#
#   Arabic English French  ...   biology   Geology AppliedMathematics   Physics  \
# 0     48      25   31.0  ...  غير مقرر  غير مقرر           غير مقرر  غير مقرر
# 1     56      41   40.0  ...  غير مقرر  غير مقرر           غير مقرر  غير مقرر
# 2     53      25   37.0  ...  غير مقرر  غير مقرر           غير مقرر  غير مقرر
# 3     79      37   38.0  ...  غير مقرر  غير مقرر           غير مقرر  غير مقرر
# 4     65      36   40.0  ...  غير مقرر  غير مقرر           غير مقرر  غير مقرر
#
#   Total Score Religious Education Citizenship Education  \
# 0       224.0                20.0                  13.0
# 1       284.0                18.0                  18.0
# 2       236.0                20.0                  18.0
# 3       359.0                17.0                  20.0
# 4       286.0                16.0                  19.0
#
#   Economics and Statistics Percentage Unnamed: 0
# 0                       26      54.63        NaN
# 1                       32      69.27        NaN
# 2                       28      57.56        NaN
# 3                       29      87.56        NaN
# 4                       27      69.76        NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# <h1>Data cleaning </h1>

# %% [markdown]
# <h5> 1-  <b style="color : blue">drop Unnamed: 0</b>  </h5>
# <p>Delete the column Unnamed: 0 because it does not help us in the analysis process</p>

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %% [markdown]
# <h3> 2- <b style="color:blue"> missing  value </b></h3>
# <p> it is clear to us that the missing value in the data don't exceed 1 % ,so we can drop it</p>

# %%
np.round((df.isnull().sum().sum() / len(df))*100,2)
# Out:
# 0.35

# %%
df.dropna(inplace=True)

# %% [markdown]
# <h3>3- <b style="color:blue">fix some value in the columns </b></h3>
# <p> some value in the data has a <b style="color : red "> غائب , مؤجل ,غير مقرر </b> that we can replace it bt zero</p>

# %%
df['Arabic']= df['Arabic'].replace(('غائب','مؤجل','غير مقرر'),(0,0,0)) 
df['English']= df['English'].replace(('غائب','مؤجل','غير مقرر'),(0,0,0))
df['French']= df['French'].replace(('غائب','مؤجل','غير مقرر'),(0,0,0))
df['pure_mathematics']= df['pure_mathematics'].replace(('غائب','مؤجل','غير مقرر'),(0,0,0))
df['history']=df['history'].replace(('غائب','مؤجل','غير مقرر'),(0,0,0))
df['geography']=df['geography'].replace(('غائب','مؤجل','غير مقرر'),(0,0,0))
df['philosophy']=df['philosophy'].replace(('غائب','مؤجل','غير مقرر'),(0,0,0))
df['psychology and sociology']=df['psychology and sociology'].replace(('غائب','مؤجل','غير مقرر'),(0,0,0))
df['chemistry']=df['chemistry'].replace(('غائب','مؤجل','غير مقرر'),(0,0,0))
df['biology']=df['biology'].replace(('غائب','مؤجل','غير مقرر'),(0,0,0))
df['Geology']=df['Geology'].replace(('غائب','مؤجل','غير مقرر'),(0,0,0))
df['AppliedMathematics']=df['AppliedMathematics'].replace(('غائب','مؤجل','غير مقرر'),(0,0,0))
df['Physics']=df['Physics'].replace(('غائب','مؤجل','غير مقرر'),(0,0,0))
df['Economics and Statistics']=df['Economics and Statistics'].replace(('غائب','مؤجل','غير مقرر'),(0,0,0))
df['Religious Education']=df['Religious Education'].replace(('غائب','مؤجل','غير مقرر'),(0,0,0))
df['Citizenship Education']=df['Citizenship Education'].replace(('غائب','مؤجل','غير مقرر'),(0,0,0))

# %%
df.query("history=='غائب'").count()[0],df.query("history=='مؤجل'").count()[0],df.query("history=='غير مقرر'").count()[0]
# Out:
# (0, 0, 0)

# %%
df.head()
# Out:
#    Unnamed: 0.1  student_id                 Student_name  \
# 0             0     1002330        ابراهيم سعيد محمد فرج
# 1             1     1002331        احمد حسام السيد حارون
# 2             2     1002332      احمد صلاح حسن احمد جعفر
# 3             3     1002333  توفيق محمد توفيق مهران قاسم
# 4             4     1002334           زياد حسن محمد احمد
#
#                            School Administration Division Student_status  \
# 0  النور ث للمكفوفين بالجيزة بنين          الدقى     أدبي           ناجح
# 1  النور ث للمكفوفين بالجيزة بنين          الدقى     أدبي           ناجح
# 2  النور ث للمكفوفين بالجيزة بنين          الدقى     أدبي           ناجح
# 3  النور ث للمكفوفين بالجيزة بنين          الدقى     أدبي           ناجح
# 4  النور ث للمكفوفين بالجيزة بنين          الدقى     أدبي           ناجح
#
#   Arabic English French  ... chemistry biology Geology AppliedMathematics  \
# 0     48      25   31.0  ...         0       0       0                  0
# 1     56      41   40.0  ...         0       0       0                  0
# 2     53      25   37.0  ...         0       0       0                  0
# 3     79      37   38.0  ...         0       0       0                  0
# 4     65      36   40.0  ...         0       0       0                  0
#
#   Physics Total Score Religious Education Citizenship Education  \
# 0       0       224.0                20.0                  13.0
# 1       0       284.0                18.0                  18.0
# 2       0       236.0                20.0                  18.0
# 3       0       359.0                17.0                  20.0
# 4       0       286.0                16.0                  19.0
#
#   Economics and Statistics Percentage
# 0                       26      54.63
# 1                       32      69.27
# 2                       28      57.56
# 3                       29      87.56
# 4                       27      69.76
#
# [5 rows x 25 columns]

# %% [markdown]
# <h3 >4- <b style="color: blue "> Division </b><h3>

# %%
df['Division'].value_counts()
# Out:
# Division
# علمي علوم      40666
# أدبي           33005
# علمي رياضة      9489
#  غير محدد         93
#  أدبي             55
# غير محدد          29
#  علمي علوم        10
#  علمي رياضة        4
# Name: count, dtype: int64

# %% [markdown]
# > to fixd this columns i will used a strip function to delete the spaces

# %%
df['Division']=df['Division'].apply(lambda x: x.strip())

# %%
df['Division'].value_counts()
# Out:
# Division
# علمي علوم     40676
# أدبي          33060
# علمي رياضة     9493
# غير محدد        122
# Name: count, dtype: int64

# %%
df[df['Division']=='غير محدد']
# Out:
#        Unnamed: 0.1  student_id                     Student_name  \
# 460             460     1002970         محمد هشام مصطفي الشعراوي
# 461             461     1002975               يوسف حازم علي شيحه
# 462             462     1003001      فريده حسام الدين محمود ماهر
# 463             463     1003016    ناديه احمد خليل ابراهيم حسنين
# 464             464     1003053        احمد شريف حلمي احمد عيسوي
# ...             ...         ...                              ...
# 74087          3405     1109027             ملك مدين شريف البقلي
# 74088          3406     1109028  يارا علاءالدين عادل مدبولي احمد
# 74089          3407     1109029     سلمي سلطان صلاح ابوطالب احمد
# 74090          3408     1109030          سلمي محمد عبدالنبي عطيه
# 74091          3409     1109031              مريم فاضل فاضل ديغم
#
#                                     School Administration  Division  \
# 460    الالمانية الانجيلية خ بنين (ابيتور)          الدقى  غير محدد
# 461    الالمانية الانجيلية خ بنين (ابيتور)          الدقى  غير محدد
# 462    الالمانية الانجيلية خ بنات (ابيتور)          الدقى  غير محدد
# 463    الالمانية الانجيلية خ بنات (ابيتور)          الدقى  غير محدد
# 464         نارمر ث خ لغات بنين(I.G.C.S.E)          الدقى  غير محدد
# ...                                    ...            ...       ...
# 74087             مدارس النيل المصريه بنات         أكتوبر  غير محدد
# 74088             مدارس النيل المصريه بنات         أكتوبر  غير محدد
# 74089             مدارس النيل المصريه بنات         أكتوبر  غير محدد
# 74090             مدارس النيل المصريه بنات         أكتوبر  غير محدد
# 74091             مدارس النيل المصريه بنات         أكتوبر  غير محدد
#
#        Student_status Arabic English French  ... chemistry biology Geology  \
# 460    راسب دور ثاني      40       0      0  ...         0       0       0
# 461    راسب دور ثاني      40       0      0  ...         0       0       0
# 462    راسب دور ثاني      40       0      0  ...         0       0       0
# 463    راسب دور ثاني       0       0      0  ...         0       0       0
# 464    راسب دور ثاني      40       0      0  ...         0       0       0
# ...               ...    ...     ...    ...  ...       ...     ...     ...
# 74087            ناجح      0       0     33  ...         0       0       0
# 74088            ناجح      0       0   35.5  ...         0       0       0
# 74089            ناجح      0       0   معفى  ...         0       0       0
# 74090            ناجح      0       0   معفى  ...         0       0       0
# 74091            ناجح      0       0   معفى  ...         0       0       0
#
#       AppliedMathematics Physics Total Score Religious Education  \
# 460                    0       0         0.0                  13
# 461                    0       0         0.0                  16
# 462                    0       0         0.0                  17
# 463                    0       0         0.0                   0
# 464                    0       0         0.0                  13
# ...                  ...     ...         ...                 ...
# 74087                  0       0         0.0                  18
# 74088                  0       0         0.0                  21
# 74089                  0       0         0.0                  22
# 74090                  0       0         0.0                  21
# 74091                  0       0         0.0                  23
#
#       Citizenship Education Economics and Statistics Percentage
# 460                      15                        0        0.0
# 461                      14                        0        0.0
# 462                      19                        0        0.0
# 463                      13                        0        0.0
# 464                      19                        0        0.0
# ...                     ...                      ...        ...
# 74087                    21                        0        0.0
# 74088                    22                        0        0.0
# 74089                    21                        0        0.0
# 74090                    20                        0        0.0
# 74091                    21                        0        0.0
#
# [122 rows x 25 columns]

# %%
df.drop(df[df['Division'] == 'غير محدد'].index, axis=0, inplace=True)

# %% [markdown]
# <h3>5- <b style = "color:blue">fixed some values in columns</b><h3>

# %% [markdown]
# <h3> A- <b style="color:yellow"> ملغى </b> </h3>
# <h4>There are some students for whom the exam was canceled. This may be due to the fact that he cheated, so to solve this problem, we will compensate for it with zero.</h4>

# %%
df[df['Arabic']=='ملغى']
# Out:
#        Unnamed: 0.1  student_id                     Student_name  \
# 60005          3543     1080670       ابوعبيده حسن عمر عبدالعظيم
# 64363          7901     1087761       ريهام ايمن محمود عبدالسميع
# 65565          9103     1089579            فارس هشام محمد سليمان
# 65868          9406     1090005         محمد سعيد عبدالرحمن محمد
# 66825         10363     1091426          شهد ايمن يحيا عبدالفتاح
# 68385         11923     1094016         اياد ياسر سعدالدين محروس
# 68850         12388     1094821  محمد عبدالسلام نصرالله عبدالغني
# 71037           355     1101680         محمد سامي محمد عبدالمجيد
# 71307           625     1102115     عبدالرحمن احمد محمد عيد سالم
# 71441           759     1102388  محمد السيد ابراهيم محمد الخلالى
# 75092          4410     1302698        يوسف شحاته حامد شحاته بدر
#
#                                               School Administration  \
# 60005            خدمات الشهيد عبد المنعم رياض ث بنين            ببا
# 64363  الشهيد مصطفى احمد عبد المجيد محمود عبيدو بنات  منشأة القناطر
# 65565                      الدعوة الاسلامية ث خ بنين       بنى سويف
# 65868                  الشهيد عبد المنعم رياض ث بنين            ببا
# 66825                                العجميين ث بنات         ابشواى
# 68385            خدمات الشهيد عبد المنعم رياض ث بنين            ببا
# 68850                 خدمات عويس عليوة ث بنين بسنهور          سنورس
# 71037                       منازل ادارة العجوزة بنين        العجوزة
# 71307                 منازل ادارة بولاق الدكرور بنين  بولاق الدكرور
# 71441                         منازل ادارة الهرم بنين          الهرم
# 75092                       منازل إدارة   بركة السبع     بركة السبع
#
#          Division Student_status Arabic English French  ... chemistry biology  \
# 60005        أدبي   راسب دور أول   ملغى       3     20  ...         0       0
# 64363   علمي علوم   راسب دور أول   ملغى       9     20  ...      14.5      30
# 65565        أدبي   راسب دور أول   ملغى    ملغى     27  ...         0       0
# 65868   علمي علوم   راسب دور أول   ملغى       0     30  ...         2       1
# 66825   علمي علوم   راسب دور أول   ملغى    ملغى   ملغى  ...      ملغى    ملغى
# 68385        أدبي   راسب دور أول   ملغى      32     20  ...         0       0
# 68850        أدبي   راسب دور أول   ملغى    ملغى   ملغى  ...         0       0
# 71037   علمي علوم   راسب دور أول   ملغى    ملغى     34  ...      ملغى    ملغى
# 71307   علمي علوم   راسب دور أول   ملغى    ملغى   ملغى  ...      ملغى      31
# 71441        أدبي   راسب دور أول   ملغى      30     20  ...         0       0
# 75092  علمي رياضة   راسب دور أول   ملغى    ملغى   ملغى  ...      ملغى       0
#
#       Geology AppliedMathematics Physics Total Score Religious Education  \
# 60005       0                  0       0       109.0                  16
# 64363      30                  0      30       133.5                  15
# 65565       0                  0       0       117.0                  22
# 65868      48                  0       0        81.0                  21
# 66825    ملغى                  0    ملغى         0.0                  16
# 68385       0                  0       0       149.5                  13
# 68850       0                  0       0       132.0                  16
# 71037    ملغى                  0    ملغى        34.0              إجتياز
# 71307      48                  0    ملغى        79.0              إجتياز
# 71441       0                  0       0       110.0                  19
# 75092       0               ملغى    ملغى         0.0                ملغى
#
#       Citizenship Education Economics and Statistics Percentage
# 60005                     7                       25      26.59
# 64363                    13                       25      32.56
# 65565                    16                       25      28.54
# 65868                    20                       26      19.76
# 66825                    18                       25       0.00
# 68385                    14                       25      36.46
# 68850                    15                       25      32.20
# 71037                إجتياز                   إجتياز       8.29
# 71307                إجتياز                   إجتياز      19.27
# 71441                    14                       25      26.83
# 75092                  ملغى                     ملغى       0.00
#
# [11 rows x 25 columns]

# %%
df['history']=df['history'].replace('ملغى',0)
df['chemistry']=df['chemistry'].replace('ملغى',0)
df['biology']=df['biology'].replace('ملغى',0)
df['Geology']=df['Geology'].replace('ملغى',0)
df['Physics']=df['Physics'].replace('ملغى',0)
df['pure_mathematics']=df['pure_mathematics'].replace('ملغى',0)
df['English']=df['English'].replace('ملغى',0)
df['Arabic']=df['Arabic'].replace('ملغى',0)
df['French']=df['French'].replace('ملغى',0)
df['philosophy']=df['philosophy'].replace('ملغى',0)
df['AppliedMathematics']=df['AppliedMathematics'].replace('ملغى',0)
df['Religious Education']=df['Religious Education'].replace('ملغى',0)
df['Citizenship Education']=df['Citizenship Education'].replace('ملغى',0)
df['Economics and Statistics']=df['Economics and Statistics'].replace('ملغى',0)

# %% [markdown]
# <h2> B- <b style="color:yellow">French </b> </h2>
# <p>As for the column for grades in the French subject, note that there is an exempt value in the column. This means that the student has passed the exam before, and this can be seen from the total grades for the subjects.
# Therefore, to solve this problem, we will add the student’s grades in the subjects and subtract them from the total sum of the subjects</p>

# %% [markdown]
# <h3>We convert the data type to the important subjects that will be added to the student’s total grades</h3>

# %%
df = df.astype({'Arabic': float, 'English': float,
            'pure_mathematics': float, 'history': float,'geography':float,'philosophy':float,'psychology and sociology':float,
            'chemistry':float,'biology':float,'Geology':float,'AppliedMathematics':float,'Physics':float})

# %%
pd.options.display.max_columns = None
df[df['French']=='معفى']
# Out:
#        Unnamed: 0.1  student_id                     Student_name  \
# 174             174     1002623             الهام سمير السيد علي
# 175             175     1002624               ملك عصام صالح محمد
# 176             176     1002625           الاء حسين ابراهيم حسين
# 177             177     1002626         جني عاطف ابراهيم اسماعيل
# 180             180     1002629             حبيبه محمد كامل محمد
# ...             ...         ...                              ...
# 81190         10508     1451962     مروه خالد احمد حسين الشرقاوى
# 81548         10866     1452359            رنا محمد حسن حسن كسبر
# 81549         10867     1452360  مريم ابراهيم شريف متولي ابراهيم
# 81864         11182     1452886         يوسف محمد حسن صالح السيد
# 82007         11325     1453047       ساره محمد المغاورى نصر عمر
#
#                             School Administration   Division Student_status  \
# 174                 الاوقاف ث بنات        العجوزة       أدبي           ناجح
# 175                 الاوقاف ث بنات        العجوزة       أدبي           ناجح
# 176                 العجوزة ث بنات        العجوزة       أدبي           ناجح
# 177                 العجوزة ث بنات        العجوزة  علمي علوم           ناجح
# 180          الكرامة الثانوية بنات        العجوزة       أدبي           ناجح
# ...                            ...            ...        ...            ...
# 81190          الشهيد/ عزت الشافعى  شرق كفر الشيخ  علمي علوم           ناجح
# 81548            سخا الثانويه بنات  شرق كفر الشيخ  علمي علوم           ناجح
# 81549            سخا الثانويه بنات  شرق كفر الشيخ  علمي علوم           ناجح
# 81864  الابراهيمية الخاصة الثانوية  غرب كفر الشيخ       أدبي           ناجح
# 82007  الابراهيمية الخاصة الثانوية  غرب كفر الشيخ  علمي علوم   راسب دور أول
#
#        Arabic  English French  pure_mathematics  history  geography  \
# 174      67.0     25.0   معفى               0.0     45.0       52.0
# 175      67.0     26.0   معفى               0.0     35.0       54.0
# 176      61.0     25.0   معفى               0.0     55.0       38.0
# 177      76.0     40.0   معفى               0.0      0.0        0.0
# 180      64.0     28.0   معفى               0.0     53.0       45.0
# ...       ...      ...    ...               ...      ...        ...
# 81190    70.5     45.5   معفى               0.0      0.0        0.0
# 81548    47.0     30.0   معفى               0.0      0.0        0.0
# 81549    66.5     40.5   معفى               0.0      0.0        0.0
# 81864    57.0     36.0   معفى               0.0     48.0       36.0
# 82007    27.5     25.0   معفى               0.0      0.0        0.0
#
#        philosophy  psychology and sociology  chemistry  biology  Geology  \
# 174          52.0                      42.0        0.0      0.0      0.0
# 175          52.0                      42.0        0.0      0.0      0.0
# 176          42.0                      30.0        0.0      0.0      0.0
# 177           0.0                       0.0       58.0     56.0     53.0
# 180          42.0                      46.0        0.0      0.0      0.0
# ...           ...                       ...        ...      ...      ...
# 81190         0.0                       0.0       41.0     45.5     56.0
# 81548         0.0                       0.0       41.0     44.0     33.5
# 81549         0.0                       0.0       55.0     52.0     56.5
# 81864        54.0                      48.0        0.0      0.0      0.0
# 82007         0.0                       0.0       30.0     30.0     24.5
#
#        AppliedMathematics  Physics  Total Score Religious Education  \
# 174                   0.0      0.0        283.0                  19
# 175                   0.0      0.0        276.0                  16
# 176                   0.0      0.0        251.0                  18
# 177                   0.0     50.0        333.0                  22
# 180                   0.0      0.0        278.0                  22
# ...                   ...      ...          ...                 ...
# 81190                 0.0     41.5        300.0                  22
# 81548                 0.0     39.5        235.0                  17
# 81549                 0.0     55.0        325.5                  23
# 81864                 0.0      0.0        279.0                  18
# 82007                 0.0     30.0        167.0                  21
#
#       Citizenship Education Economics and Statistics  Percentage
# 174                      23                     25.0       69.02
# 175                      23                     25.5       67.32
# 176                      15                     25.0       61.22
# 177                      23                     35.0       81.22
# 180                      22                     29.0       67.80
# ...                     ...                      ...         ...
# 81190                    22                       43       73.17
# 81548                    19                       30       57.32
# 81549                    20                       34       79.39
# 81864                    17                     30.5       68.05
# 82007                    10                       12       40.73
#
# [448 rows x 25 columns]

# %%
def calculate_french_score(row):
    if row['French'] == 'معفى':
        return 0
    else:
        return row['French']
    
df['French'] = df.apply(calculate_french_score, axis=1)

# %% [markdown]
# <h3> C- <b style="color:yellow"> Passed value </b> </h3>
# For subjects that are not added to the total, there are some values such as Passed, which means that the student has passed the exam, so we will compensate for it with the average for each column.

# %%
df[df['Religious Education']=='إجتياز']
# Out:
#        Unnamed: 0.1  student_id                  Student_name  \
# 425             425     1002880          اسراء شوقي مهدي محمد
# 429             429     1002884         ايه مصطفي فاروق السيد
# 434             434     1002889     رحاب عبدالقادر احمد محمود
# 441             441     1002896          ايمان ايمن احمد محمد
# 1067           1067     1002880          اسراء شوقي مهدي محمد
# ...             ...         ...                           ...
# 75325          4643     1304753   روان ايهاب محمود محمد محمود
# 75326          4644     1304806     روفيدا احمد محروس ابراهيم
# 75327          4645     1304807          امينه احمد محمود سعد
# 75328          4646     1304928          عبدالله على حسن احمد
# 75329          4647     1304950  عيسى محمد صالح حسن حسب النبى
#
#                                School Administration    Division  \
# 425    منازل ادارة منشأة القناطر بنات  منشأة القناطر   علمي علوم
# 429            منازل ادارة اوسيم بنات          اوسيم        أدبي
# 434           منازل ادارة العياط بنات         العياط        أدبي
# 441          منازل ادارة العجوزة بنات        العجوزة   علمي علوم
# 1067   منازل ادارة منشأة القناطر بنات  منشأة القناطر   علمي علوم
# ...                               ...            ...         ...
# 75325            منازل إدارة   قويسنا         قويسنا  علمي رياضة
# 75326           منازل إدارة   الشهداء        الشهداء        أدبي
# 75327           منازل إدارة   الشهداء        الشهداء   علمي علوم
# 75328          منازل إدارة   مرسى علم       مرسى علم        أدبي
# 75329          منازل إدارة   شلاتيــن       شلاتيــن        أدبي
#
#       Student_status  Arabic  English French  pure_mathematics  history  \
# 425             ناجح    74.0     35.0     28               0.0      0.0
# 429             ناجح    40.0     25.0     35               0.0     30.0
# 434             ناجح    44.0     25.0     20               0.0     30.0
# 441             ناجح    40.0     28.0     30               0.0      0.0
# 1067            ناجح    74.0     35.0     28               0.0      0.0
# ...              ...     ...      ...    ...               ...      ...
# 75325           ناجح    58.5     31.5     29              41.5      0.0
# 75326           ناجح    49.0     35.0     20               0.0     30.0
# 75327           ناجح    42.0     38.0     20               0.0      0.0
# 75328           ناجح    40.0     40.0     21               0.0     37.0
# 75329           ناجح    40.0     41.0     20               0.0     30.0
#
#        geography  philosophy  psychology and sociology  chemistry  biology  \
# 425          0.0         0.0                       0.0       51.0     50.0
# 429         30.0        35.0                      30.0        0.0      0.0
# 434         30.0        32.0                      52.0        0.0      0.0
# 441          0.0         0.0                       0.0       30.0     30.0
# 1067         0.0         0.0                       0.0       51.0     50.0
# ...          ...         ...                       ...        ...      ...
# 75325        0.0         0.0                       0.0       30.0      0.0
# 75326       33.0        30.0                      40.0        0.0      0.0
# 75327        0.0         0.0                       0.0       30.0     30.0
# 75328       30.0        30.0                      33.0        0.0      0.0
# 75329       30.0        42.0                      34.0        0.0      0.0
#
#        Geology  AppliedMathematics  Physics  Total Score Religious Education  \
# 425       32.0                 0.0     30.0        300.0              إجتياز
# 429        0.0                 0.0      0.0        225.0              إجتياز
# 434        0.0                 0.0      0.0        233.0              إجتياز
# 441       30.0                 0.0     31.0        219.0              إجتياز
# 1067      32.0                 0.0     30.0        300.0              إجتياز
# ...        ...                 ...      ...          ...                 ...
# 75325      0.0                30.0     30.0        250.5              إجتياز
# 75326      0.0                 0.0      0.0        237.0              إجتياز
# 75327     33.0                 0.0     30.0        223.0              إجتياز
# 75328      0.0                 0.0      0.0        231.0              إجتياز
# 75329      0.0                 0.0      0.0        237.0              إجتياز
#
#       Citizenship Education Economics and Statistics  Percentage
# 425                  إجتياز                   إجتياز       73.17
# 429                  إجتياز                   إجتياز       54.88
# 434                  إجتياز                   إجتياز       56.83
# 441                  إجتياز                   إجتياز       53.41
# 1067                 إجتياز                   إجتياز       73.17
# ...                     ...                      ...         ...
# 75325                إجتياز                   إجتياز       61.10
# 75326                إجتياز                   إجتياز       57.80
# 75327                إجتياز                   إجتياز       54.39
# 75328                إجتياز                   إجتياز       56.34
# 75329                إجتياز                   إجتياز       57.80
#
# [2879 rows x 25 columns]

# %%
numerical_value= df[df['Religious Education']!='إجتياز']
numerical_value['Religious Education']=numerical_value['Religious Education'].astype(float)
numerical_mean=np.round(numerical_value['Religious Education'].mean(),2)
df['Religious Education']=df['Religious Education'].replace('إجتياز',numerical_mean)
numerical_mean
# Out:
# C:\Users\Ebrahim\AppData\Local\Temp\ipykernel_8596\1735801365.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numerical_value['Religious Education']=numerical_value['Religious Education'].astype(float)
# 17.58

# %%
#Citizenship Education
numerical_value= df[df['Citizenship Education']!='إجتياز']
numerical_value['Citizenship Education']=numerical_value['Citizenship Education'].astype(float)
numerical_mean=np.round(numerical_value['Citizenship Education'].mean(),2)
df['Citizenship Education']=df['Citizenship Education'].replace('إجتياز',numerical_mean)
numerical_mean
# Out:
# C:\Users\Ebrahim\AppData\Local\Temp\ipykernel_8596\3957886915.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numerical_value['Citizenship Education']=numerical_value['Citizenship Education'].astype(float)
# 17.32

# %%
#Economics and Statistics
numerical_value= df[df['Economics and Statistics']!='إجتياز']
numerical_value['Economics and Statistics']=numerical_value['Economics and Statistics'].astype(float)
numerical_mean=np.round(numerical_value['Economics and Statistics'].mean(),2)
df['Economics and Statistics']=df['Economics and Statistics'].replace('إجتياز',numerical_mean)
numerical_mean
# Out:
# C:\Users\Ebrahim\AppData\Local\Temp\ipykernel_8596\2607942328.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numerical_value['Economics and Statistics']=numerical_value['Economics and Statistics'].astype(float)
# 27.11

# %%
df['Student_status']=df['Student_status'].apply(lambda x: x.strip())
df['Student_status'].unique()
# Out:
# array(['ناجح', 'ناجح دور ثاني', 'راسب دور ثاني', 'راسب دور أول'],
#       dtype=object)

# %% [markdown]
# <h3> D- <b style="color:yellow"> change some value of the columns  </b> </h3>

# %%
df['Student_status']=df['Student_status'].replace(('ناجح','راسب دور أول','راسب دور ثاني','ناجح دور ثاني',),('successful','Failed first round','Failed second round','Successful second round'))
df['Division']=df['Division'].replace(('علمي علوم','أدبي','علمي رياضة'),('science','literary','mathematics_branch'))

# %%
df['Student_status'].value_counts()
# Out:
# Student_status
# successful                 75245
# Failed first round          7915
# Successful second round       57
# Failed second round           12
# Name: count, dtype: int64

# %% [markdown]
# <h2>7-<b style="color :blue"> create new features  </b> </h2>

# %% [markdown]
# <h3> A- <b style="color:yellow"> create   governorate columns</b> </h3>

# %%
df['Administration'].unique()
# Out:
# array(['الدقى', 'أكتوبر', 'أكتوبر ', 'غرب الفيوم', 'بنى سويف', 'الزيتون',
#        'النزهة', 'مدينة السلام', 'بنها', 'شبين الكوم', 'شمال الاسماعيلية',
#        'الغردقة', 'غرب الزقازيق', 'دمياط', 'غرب المنصورة', 'شمال السويس',
#        'الزهور', 'العريش', 'غرب طنطا', 'شرق الأسكندرية', 'العجوزة',
#        'بولاق الدكرور', 'الهرم', 'حدائق أكتوبر', ' حدائق أكتوبر',
#        'الشيخ زايد', 'اوسيم', 'كرداسة', 'منشأة القناطر', 'ابو النمرس',
#        'الحوامدية', 'البدرشين', 'العياط', 'الواسطى', 'الفشن', 'ببا',
#        'ناصر', 'سمسطا', 'شرق الفيوم', 'اطسا', 'سنورس', 'ابشواى',
#        'الواحات البحرية', 'اهناسيا', 'يوسف الصديق', 'طامية', 'العمرانية',
#        'الوراق', 'الصف', 'اطفيح', 'منوف', 'سرس الليان', 'السادات', 'تلا',
#        'اشمون', 'قويسنا', 'الباجور', 'الشهداء', 'بركة السبع', 'القصير',
#        'رأس غارب', 'سفاجا', 'حلايب', 'شلاتيــن', 'شرق مدينة نصر',
#        'الخليفة', 'مصر القديمة', 'شمال الجيزة', 'جنوب الجيزة', 'مرسى علم',
#        'الجمرك', 'شرق كفر الشيخ', 'غرب كفر الشيخ', 'سيدى غازى', 'الرياض',
#        'سيدى سالم'], dtype=object)

# %%
df['Administration'].nunique()
# Out:
# 76

# %%
df['Administration']=df['Administration'].apply(lambda x: x.strip())

# %%
administration_list=list(df['Administration'].unique())
administration_list
# Out:
# ['الدقى',
#  'أكتوبر',
#  'غرب الفيوم',
#  'بنى سويف',
#  'الزيتون',
#  'النزهة',
#  'مدينة السلام',
#  'بنها',
#  'شبين الكوم',
#  'شمال الاسماعيلية',
#  'الغردقة',
#  'غرب الزقازيق',
#  'دمياط',
#  'غرب المنصورة',
#  'شمال السويس',
#  'الزهور',
#  'العريش',
#  'غرب طنطا',
#  'شرق الأسكندرية',
#  'العجوزة',
#  'بولاق الدكرور',
#  'الهرم',
#  'حدائق أكتوبر',
#  'الشيخ زايد',
#  'اوسيم',
#  'كرداسة',
#  'منشأة القناطر',
#  'ابو النمرس',
#  'الحوامدية',
#  'البدرشين',
#  'العياط',
#  'الواسطى',
#  'الفشن',
#  'ببا',
#  'ناصر',
#  'سمسطا',
#  'شرق الفيوم',
#  'اطسا',
#  'سنورس',
#  'ابشواى',
#  'الواحات البحرية',
#  'اهناسيا',
#  'يوسف الصديق',
#  'طامية',
#  'العمرانية',
#  'الوراق',
#  'الصف',
#  'اطفيح',
#  'منوف',
#  'سرس الليان',
#  'السادات',
#  'تلا',
#  'اشمون',
#  'قويسنا',
#  'الباجور',
#  'الشهداء',
#  'بركة السبع',
#  'القصير',
#  'رأس غارب',
#  'سفاجا',
#  'حلايب',
#  'شلاتيــن',
#  'شرق مدينة نصر',
#  'الخليفة',
#  'مصر القديمة',
#  'شمال الجيزة',
#  'جنوب الجيزة',
#  'مرسى علم',
#  'الجمرك',
#  'شرق كفر الشيخ',
#  'غرب كفر الشيخ',
#  'سيدى غازى',
#  'الرياض',
#  'سيدى سالم']

# %%
geolocator = Nominatim(user_agent="Data Science Course")
location = list(geolocator.geocode('طامية'))
location =location[0].strip().split(',')
location[-3].strip()
# Out:
# 'محافظة الفيوم'

# %%
location_dict={}
for i in administration_list :
    try:
        location = list(geolocator.geocode(f' مصر- {i}'))
        location =location[0].strip().split(',')
        location = location[-3].strip()
        
        location_dict[i]=location
    except:
        continue
location_dict
# Out:
# {'الدقى': 'الجيزة',
#  'أكتوبر': 'مدينة السادس من أكتوبر',
#  'الزيتون': 'القاهرة',
#  'النزهة': 'القاهرة',
#  'مدينة السلام': 'القليوبية',
#  'بنها': 'القليوبية',
#  'شبين الكوم': 'المنوفية',
#  'شمال الاسماعيلية': 'الجفجافه',
#  'الغردقة': 'البحر الأحمر',
#  'غرب الزقازيق': 'الإسماعيلية',
#  'دمياط': 'دمياط',
#  'الزهور': 'بورسعيد',
#  'العريش': 'العريش',
#  'غرب طنطا': 'الإسماعيلية',
#  'شرق الأسكندرية': 'الإسكندرية',
#  'العجوزة': 'الجيزة',
#  'بولاق الدكرور': 'الجيزة',
#  'الهرم': 'الجيزة',
#  'حدائق أكتوبر': 'الجيزة',
#  'الشيخ زايد': 'الجيزة',
#  'اوسيم': 'الجيزة',
#  'كرداسة': 'الجيزة',
#  'منشأة القناطر': 'الجيزة',
#  'ابو النمرس': 'الجيزة',
#  'الحوامدية': 'الجيزة',
#  'البدرشين': 'الجيزة',
#  'العياط': 'الجيزة',
#  'الواسطى': 'بنى سويف',
#  'الفشن': 'بنى سويف',
#  'ببا': 'بنى سويف',
#  'ناصر': 'سوهاج',
#  'سمسطا': 'بنى سويف',
#  'اطسا': 'محافظة الفيوم',
#  'سنورس': 'محافظة الفيوم',
#  'ابشواى': 'محافظة الفيوم',
#  'الواحات البحرية': 'الجيزة',
#  'اهناسيا': 'بنى سويف',
#  'يوسف الصديق': 'يوسف الصديق',
#  'طامية': 'محافظة الفيوم',
#  'العمرانية': 'الجيزة',
#  'الوراق': 'الغربية',
#  'الصف': 'الجيزة',
#  'اطفيح': 'الجيزة',
#  'منوف': 'المنوفية',
#  'سرس الليان': 'المنوفية',
#  'السادات': 'مدينة السادات',
#  'تلا': 'المنوفية',
#  'اشمون': 'المنوفية',
#  'قويسنا': 'المنوفية',
#  'الباجور': 'المنوفية',
#  'الشهداء': 'المنوفية',
#  'بركة السبع': 'الغربية',
#  'القصير': 'البحر الأحمر',
#  'رأس غارب': 'البحر الأحمر',
#  'سفاجا': 'البحر الأحمر',
#  'حلايب': 'حلايب',
#  'شلاتيــن': 'Suhein',
#  'شرق مدينة نصر': 'القاهرة',
#  'الخليفة': 'القاهرة',
#  'مصر القديمة': 'القاهرة',
#  'شمال الجيزة': 'القاهرة',
#  'مرسى علم': 'البحر الأحمر',
#  'الجمرك': 'الإسكندرية',
#  'شرق كفر الشيخ': 'الإسماعيلية',
#  'غرب كفر الشيخ': 'الإسماعيلية',
#  'سيدى غازى': 'الغربية',
#  'الرياض': 'دمياط',
#  'سيدى سالم': 'كفر الشيخ'}

# %%
location_dict['ناصر']='بني سويف'
location_dict['يوسف الصديق']='الفيوم'

# %%
def Governorate(row):
    administration_value = row['Administration']
    if administration_value in location_dict:
        return str(location_dict[administration_value])
    elif administration_value=='غرب الفيوم' or administration_value=='شرق الفيوم':
        return 'Fayoum'
    elif administration_value=='بنى سويف':
        return 'Bani Sweif'
    elif administration_value=='غرب المنصورة':
        return 'Mansoura'
    
    elif administration_value=='شمال السويس':
        return 'Suze'
    elif administration_value=='جنوب الجيزة':
        return 'Giza'

df['governorate'] = df.apply(Governorate, axis=1)

# %%
df[df['governorate'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, student_id, Student_name, School, Administration, Division, Student_status, Arabic, English, French, pure_mathematics, history, geography, philosophy, psychology and sociology, chemistry, biology, Geology, AppliedMathematics, Physics, Total Score, Religious Education, Citizenship Education, Economics and Statistics, Percentage, governorate]
# Index: []

# %%
df['governorate']=df['governorate'].apply(lambda x: x.strip())
df['governorate']=df['governorate'].replace(('بنى سويف','الجيزة','محافظة الفيوم','المنوفية','الإسكندرية','الشرقية','القليوبية','دمياط','البحر الأحمر','العريش'),('Bani Sweif','Giza','Fayoum','Menoufia','Alexandria','alsharqia','Qalyubia','Damietta','The Red Sea','Arish'))
df['governorate']=df['governorate'].replace(('بني سويف','كفر الشيخ','حلايب','الغربية','بورسعيد','الإسماعيلية','مدينة السادات','الفيوم','مدينة السادس من أكتوبر','القاهرة','الجفجافه'),
                                            ('Bani Sweif','Kafr El-Sheikh','Halayeb','algharbia','Port Said','Ismailia','Menoufia','Fayoum','Giza','Cairo','North Sinai'))

# %%
df['governorate'].value_counts()
# Out:
# governorate
# Giza              42756
# Bani Sweif        15952
# Fayoum            15079
# Alexandria         4084
# Ismailia           2631
# Damietta            988
# Menoufia            664
# algharbia           480
# Kafr El-Sheikh      271
# Cairo               197
# The Red Sea          35
# North Sinai          30
# Qalyubia             19
# Mansoura             18
# Port Said            14
# Suhein                4
# Halayeb               3
# Suze                  2
# Arish                 2
# Name: count, dtype: int64

# %% [markdown]
# <h3> A- <b style="color:yellow"> create   gender columns</b> </h3>

# %%
df[df['School'].str.contains('بنات')]
# Out:
#        Unnamed: 0.1  student_id                          Student_name  \
# 12               12     1002342      اسراء محمد عبدالنبي محمد اسماعيل
# 13               13     1002343          اماني سعد محمد محمد علي سالم
# 14               14     1002344                    رحمه رجب محمد فؤاد
# 15               15     1002345           رحمه محمد ابوالنجا عبدالغني
# 16               16     1002346          شهد صلاح الدين علي عبدالباقي
# ...             ...         ...                                   ...
# 83108         12426     1454365                 الاء محمد خليل الصادق
# 83109         12427     1454366    امانى عبد الحكيم السيد محمود مجاهد
# 83110         12428     1454367                رانيا محمود محمد عثمان
# 83111         12429     1454368  سلمى زين محمد عبدالحميد متولى القاضى
# 83112         12430     1454369         ندا ماجد محمود محمد شرف الدين
#
#                                School Administration            Division  \
# 12     النور ث للمكفوفين بالجيزة بنات          الدقى            literary
# 13     النور ث للمكفوفين بالجيزة بنات          الدقى            literary
# 14     النور ث للمكفوفين بالجيزة بنات          الدقى            literary
# 15     النور ث للمكفوفين بالجيزة بنات          الدقى            literary
# 16     النور ث للمكفوفين بالجيزة بنات          الدقى            literary
# ...                               ...            ...                 ...
# 83108    عابد عبدالعال  الثانوية بنات         الرياض  mathematics_branch
# 83109    عابد عبدالعال  الثانوية بنات         الرياض  mathematics_branch
# 83110    عابد عبدالعال  الثانوية بنات         الرياض  mathematics_branch
# 83111    عابد عبدالعال  الثانوية بنات         الرياض  mathematics_branch
# 83112    عابد عبدالعال  الثانوية بنات         الرياض  mathematics_branch
#
#                 Student_status  Arabic  English French  pure_mathematics  \
# 12                  successful    46.0     25.0   32.0               0.0
# 13                  successful    70.0     42.0   37.0               0.0
# 14     Successful second round    44.0     25.0   31.0               0.0
# 15                  successful    69.0     39.0   27.0               0.0
# 16                  successful    72.0     42.0   39.0               0.0
# ...                        ...     ...      ...    ...               ...
# 83108               successful    51.0     25.0   35.5              30.0
# 83109               successful    72.0     48.0   36.5              53.0
# 83110               successful    49.5     25.0   28.5              44.5
# 83111               successful    73.0     46.0   38.5              47.5
# 83112               successful    56.5     38.5   38.5              39.0
#
#        history  geography  philosophy  psychology and sociology  chemistry  \
# 12        30.0       30.0        30.0                      30.0        0.0
# 13        48.0       48.0        45.0                      41.0        0.0
# 14        30.0       32.0        30.0                      30.0        0.0
# 15        44.0       39.0        37.0                      30.0        0.0
# 16        46.0       60.0        54.0                      47.0        0.0
# ...        ...        ...         ...                       ...        ...
# 83108      0.0        0.0         0.0                       0.0       30.0
# 83109      0.0        0.0         0.0                       0.0       47.0
# 83110      0.0        0.0         0.0                       0.0       30.0
# 83111      0.0        0.0         0.0                       0.0       47.0
# 83112      0.0        0.0         0.0                       0.0       30.0
#
#        biology  Geology  AppliedMathematics  Physics  Total Score  \
# 12         0.0      0.0                 0.0      0.0        223.0
# 13         0.0      0.0                 0.0      0.0        331.0
# 14         0.0      0.0                 0.0      0.0        222.0
# 15         0.0      0.0                 0.0      0.0        285.0
# 16         0.0      0.0                 0.0      0.0        360.0
# ...        ...      ...                 ...      ...          ...
# 83108      0.0      0.0                30.0     30.0        231.5
# 83109      0.0      0.0                55.5     46.5        358.5
# 83110      0.0      0.0                30.0     30.0        237.5
# 83111      0.0      0.0                47.5     44.0        343.5
# 83112      0.0      0.0                30.0     30.0        262.5
#
#       Religious Education Citizenship Education Economics and Statistics  \
# 12                   17.0                  13.0                       29
# 13                   19.0                  23.0                       26
# 14                   18.0                  12.5                       25
# 15                   16.0                  23.0                       25
# 16                   17.0                  21.0                       30
# ...                   ...                   ...                      ...
# 83108                  17                    18                       26
# 83109                  15                    16                       25
# 83110                  16                    14                       33
# 83111                  20                    20                       36
# 83112                  20                    19                       25
#
#        Percentage governorate
# 12          54.39        Giza
# 13          80.73        Giza
# 14          54.15        Giza
# 15          69.51        Giza
# 16          87.80        Giza
# ...           ...         ...
# 83108       56.46    Damietta
# 83109       87.44    Damietta
# 83110       57.93    Damietta
# 83111       83.78    Damietta
# 83112       64.02    Damietta
#
# [42416 rows x 26 columns]

# %%
def gender(row):
    school_value = row['School']

    if 'بنين' in school_value:
        return 'Male'
    elif 'بنات' in school_value:
        return 'Female'
    else:
            return 'Male'    
df['gender'] = df.apply(gender, axis=1)

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    42416
# Male      40813
# Name: count, dtype: int64

# %% [markdown]
# <h3>8-<b style="color :blue"> change type of the columns </b> </h3>

# %%
df = df.astype({'Arabic': float, 'English': float,'French':float,
            'pure_mathematics': float, 'history': float,'geography':float,'philosophy':float,'psychology and sociology':float,
            'chemistry':float,'biology':float,'Geology':float,'AppliedMathematics':float,'Physics':float,'Religious Education':float,'Citizenship Education':float,'Economics and Statistics':float})

# %% [markdown]
# <h3>9-<b style="color :blue"> fixed columns name </b> </h3>

# %%
# to remove the space between the names 
df=df.rename(columns=lambda x: x.replace(' ','_').lower())

# %%
df.columns
# Out:
# Index(['unnamed:_0.1', 'student_id', 'student_name', 'school',
#        'administration', 'division', 'student_status', 'arabic', 'english',
#        'french', 'pure_mathematics', 'history', 'geography', 'philosophy',
#        'psychology_and_sociology', 'chemistry', 'biology', 'geology',
#        'appliedmathematics', 'physics', 'total_score', 'religious_education',
#        'citizenship_education', 'economics_and_statistics', 'percentage',
#        'governorate', 'gender'],
#       dtype='object')

# %% [markdown]
# <hr>
# <hr>
# <hr>

# %% [markdown]
# <h1 style="color: yellow; text-align:center">Finally, we will save the data for the Next stage</1h>

# %%
df.to_csv('../data/processed/cleaned_data.csv')
